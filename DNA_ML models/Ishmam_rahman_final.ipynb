# %% [markdown]
# # ISHMAM RAHMAN FINAL EXAM

# %%
# Data Loading and Preprocessing
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten, Input, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization

print("--- Data Loading and Preprocessing ---")

# --- One-hot encode DNA sequences ---
def one_hot_encode_sequence(sequence, max_len):
    mapping = {
        'A': [1, 0, 0, 0], 'a': [1, 0, 0, 0],
        'T': [0, 1, 0, 0], 't': [0, 1, 0, 0],
        'G': [0, 0, 1, 0], 'g': [0, 0, 1, 0],
        'C': [0, 0, 0, 1], 'c': [0, 0, 0, 1],
        'N': [0, 0, 0, 0], 'n': [0, 0, 0, 0]
    }
    encoded = [mapping.get(char, [0, 0, 0, 0]) for char in sequence]
    encoded = np.array(encoded, dtype=np.float32)
    if len(encoded) < max_len:
        pad = np.zeros((max_len - len(encoded), 4), dtype=np.float32)
        encoded = np.vstack((encoded, pad))
    return encoded[:max_len]

# --- Load training and test data ---
train_df = pd.read_csv('dm3.kc167.tads.train.csv', header=None)
X_train_raw, y_train = train_df[0].values, train_df[1].values
test_df = pd.read_csv('dm3.kc167.tads.test.csv', header=None)
X_test_raw, y_test = test_df[0].values, test_df[1].values

# --- Encode sequences and get input shape ---
sequence_length = len(X_train_raw[0])
X_train = np.array([one_hot_encode_sequence(seq, sequence_length) for seq in X_train_raw])
X_test = np.array([one_hot_encode_sequence(seq, sequence_length) for seq in X_test_raw])
print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
input_shape = (sequence_length, 4)
print("Input shape: ",input_shape)
# Out:
# --- Data Loading and Preprocessing ---
# Train shape: (28140, 1000, 4) Test shape: (2000, 1000, 4)
# Input shape:  (1000, 4)

# %% [markdown]
# ## Model 1 - 1 layer CNN with dense layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 1 Parameters ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

# --- Build Model 1 ---
model_1 = Sequential([
    Conv1D(64, 5, activation='relu', input_shape=input_shape),
    MaxPooling1D(2),
    Dropout(0.3),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# --- Compile ---
model_1.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

# --- Callbacks ---
checkpoint = ModelCheckpoint('best_model1.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


model_1.summary()

# --- Train Model 1 ---
print("\n--- Training Model 1 ---")
history_1 = model_1.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

# --- Evaluate Model 1 ---
print("\n--- Evaluating Model 1 ---")
test_loss_1, test_acc_1 = model_1.evaluate(X_test, y_test, verbose=0)
print(f" Model 1 Test Accuracy: {test_acc_1:.4f}")
# Out:
# /opt/anaconda3/envs/ml_env/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_16 (Conv1D)              │ (None, 996, 64)        │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_13 (MaxPooling1D) │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 31872)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 64)             │     2,039,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,043,329 (7.79 MB)
#  Trainable params: 2,043,329 (7.79 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 1 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.92937, saving model to best_model1.keras
# 352/352 - 7s - 20ms/step - accuracy: 0.6059 - loss: 0.6825 - val_accuracy: 0.0000e+00 - val_loss: 0.9294
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 0.92937
# 352/352 - 6s - 18ms/step - accuracy: 0.6260 - loss: 0.6406 - val_accuracy: 0.0000e+00 - val_loss: 1.3578
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.92937 to 0.85074, saving model to best_model1.keras
# 352/352 - 6s - 18ms/step - accuracy: 0.6717 - loss: 0.5894 - val_accuracy: 0.4179 - val_loss: 0.8507
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.85074 to 0.75484, saving model to best_model1.keras
# 352/352 - 6s - 18ms/step - accuracy: 0.7281 - loss: 0.5310 - val_accuracy: 0.6269 - val_loss: 0.7548
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.7564 - loss: 0.4856 - val_accuracy: 0.4993 - val_loss: 0.9909
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.7809 - loss: 0.4409 - val_accuracy: 0.4556 - val_loss: 1.1318
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.7976 - loss: 0.4141 - val_accuracy: 0.6414 - val_loss: 0.8342
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8129 - loss: 0.3898 - val_accuracy: 0.6485 - val_loss: 0.8407
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8222 - loss: 0.3694 - val_accuracy: 0.5677 - val_loss: 1.0378
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8288 - loss: 0.3547 - val_accuracy: 0.6171 - val_loss: 0.9821
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8368 - loss: 0.3379 - val_accuracy: 0.5570 - val_loss: 1.1780
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8402 - loss: 0.3317 - val_accuracy: 0.5858 - val_loss: 1.1090
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8483 - loss: 0.3143 - val_accuracy: 0.5281 - val_loss: 1.3031
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.75484
# 352/352 - 6s - 18ms/step - accuracy: 0.8532 - loss: 0.3047 - val_accuracy: 0.5473 - val_loss: 1.4106
#
# --- Evaluating Model 1 ---
#  Model 1 Test Accuracy: 0.6915

# %% [markdown]
# ## model 2 - 2 layer CNN dense

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 2 Parameters ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

# --- Build Model 2 ---
model_2 = Sequential([
    Conv1D(64, 5, activation='relu', input_shape=input_shape),
    MaxPooling1D(2),
    Dropout(0.3),

    Conv1D(128, 5, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.3),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# --- Compile ---
model_2.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

# --- Callbacks ---
checkpoint = ModelCheckpoint('best_model2.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

model_2.summary()
# --- Train Model 2 ---
print("\n--- Training Model 2 ---")
history_2 = model_2.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

# --- Evaluate Model 2 ---
print("\n--- Evaluating Model 2 ---")
test_loss_2, test_acc_2 = model_2.evaluate(X_test, y_test, verbose=0)
print(f" Model 2 Test Accuracy: {test_acc_2:.4f}")
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_17 (Conv1D)              │ (None, 996, 64)        │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_14 (MaxPooling1D) │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_33 (Dropout)            │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_18 (Conv1D)              │ (None, 494, 128)       │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_15 (MaxPooling1D) │ (None, 247, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_34 (Dropout)            │ (None, 247, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 31616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │     2,023,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,068,033 (7.89 MB)
#  Trainable params: 2,068,033 (7.89 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 2 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.87846, saving model to best_model2.keras
# 352/352 - 19s - 54ms/step - accuracy: 0.6225 - loss: 0.6670 - val_accuracy: 0.0000e+00 - val_loss: 0.8785
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 0.87846
# 352/352 - 19s - 53ms/step - accuracy: 0.6250 - loss: 0.6509 - val_accuracy: 0.0000e+00 - val_loss: 0.9290
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.87846
# 352/352 - 19s - 53ms/step - accuracy: 0.6250 - loss: 0.6398 - val_accuracy: 0.0000e+00 - val_loss: 0.9281
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.87846 to 0.78400, saving model to best_model2.keras
# 352/352 - 19s - 53ms/step - accuracy: 0.6418 - loss: 0.6199 - val_accuracy: 0.4975 - val_loss: 0.7840
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.78400 to 0.67482, saving model to best_model2.keras
# 352/352 - 19s - 54ms/step - accuracy: 0.6857 - loss: 0.5854 - val_accuracy: 0.6963 - val_loss: 0.6748
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.67482 to 0.61569, saving model to best_model2.keras
# 352/352 - 19s - 53ms/step - accuracy: 0.7214 - loss: 0.5491 - val_accuracy: 0.7630 - val_loss: 0.6157
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.61569
# 352/352 - 19s - 53ms/step - accuracy: 0.7466 - loss: 0.5111 - val_accuracy: 0.4858 - val_loss: 0.8973
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.61569
# 352/352 - 19s - 53ms/step - accuracy: 0.7721 - loss: 0.4708 - val_accuracy: 0.7017 - val_loss: 0.6879
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.61569
# 352/352 - 19s - 53ms/step - accuracy: 0.8018 - loss: 0.4237 - val_accuracy: 0.6599 - val_loss: 0.7870
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.61569
# 352/352 - 19s - 53ms/step - accuracy: 0.8197 - loss: 0.3975 - val_accuracy: 0.6023 - val_loss: 0.8928
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.61569
# 352/352 - 19s - 53ms/step - accuracy: 0.8316 - loss: 0.3764 - val_accuracy: 0.7134 - val_loss: 0.6890
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.61569 to 0.59617, saving model to best_model2.keras
# 352/352 - 19s - 53ms/step - accuracy: 0.8545 - loss: 0.3376 - val_accuracy: 0.7624 - val_loss: 0.5962
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.59617
# 352/352 - 19s - 53ms/step - accuracy: 0.8593 - loss: 0.3270 - val_accuracy: 0.6953 - val_loss: 0.7370
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.59617
# 352/352 - 19s - 53ms/step - accuracy: 0.8686 - loss: 0.3102 - val_accuracy: 0.5997 - val_loss: 0.9535
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.59617
# 352/352 - 19s - 53ms/step - accuracy: 0.8809 - loss: 0.2894 - val_accuracy: 0.6885 - val_loss: 0.7971
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.59617
# 352/352 - 19s - 53ms/step - accuracy: 0.8847 - loss: 0.2776 - val_accuracy: 0.7061 - val_loss: 0.7542
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.59617
# 352/352 - 19s - 54ms/step - accuracy: 0.8898 - loss: 0.2653 - val_accuracy: 0.6617 - val_loss: 0.8450
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.59617
# 352/352 - 19s - 54ms/step - accuracy: 0.8957 - loss: 0.2570 - val_accuracy: 0.7207 - val_loss: 0.7211
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.59617
# 352/352 - 19s - 54ms/step - accuracy: 0.9000 - loss: 0.2501 - val_accuracy: 0.6967 - val_loss: 0.7879
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.59617
# 352/352 - 19s - 53ms/step - accuracy: 0.9091 - loss: 0.2334 - val_accuracy: 0.7647 - val_loss: 0.6391
#
# --- Evaluating Model 2 ---
#  Model 2 Test Accuracy: 0.7910

# %% [markdown]
# ## Model 3 - 3CNN  Dense

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 3 Parameters ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

# --- Build Model 3 ---
model_3 = Sequential([
    Conv1D(32, 5, activation='relu', input_shape=input_shape),
    MaxPooling1D(2),
    Dropout(0.3),

    Conv1D(64, 5, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.3),

    Conv1D(128, 5, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.3),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# --- Compile ---
model_3.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

# --- Callbacks ---
checkpoint = ModelCheckpoint('best_model3.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model_3.summary()
# --- Train Model 3 ---
print("\n--- Training Model 3 ---")
history_3 = model_3.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

# --- Evaluate Model 3 ---
print("\n--- Evaluating Model 3 ---")
test_loss_3, test_acc_3 = model_3.evaluate(X_test, y_test, verbose=0)
print(f" Model 3 Test Accuracy: {test_acc_3:.4f}")
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_19 (Conv1D)              │ (None, 996, 32)        │           672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_16 (MaxPooling1D) │ (None, 498, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_37 (Dropout)            │ (None, 498, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_20 (Conv1D)              │ (None, 494, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_17 (MaxPooling1D) │ (None, 247, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_38 (Dropout)            │ (None, 247, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 243, 128)       │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_18 (MaxPooling1D) │ (None, 121, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_39 (Dropout)            │ (None, 121, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 15488)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │       991,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_40 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_41 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,045,473 (3.99 MB)
#  Trainable params: 1,045,473 (3.99 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 3 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.83860, saving model to best_model3.keras
# 352/352 - 16s - 45ms/step - accuracy: 0.6222 - loss: 0.6654 - val_accuracy: 0.0000e+00 - val_loss: 0.8386
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 0
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.42715
# 352/352 - 15s - 43ms/step - accuracy: 0.8252 - loss: 0.3873 - val_accuracy: 0.7006 - val_loss: 0.5897
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.42715
# 352/352 - 15s - 43ms/step - accuracy: 0.8310 - loss: 0.3795 - val_accuracy: 0.6949 - val_loss: 0.5952
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.42715
# 352/352 - 15s - 43ms/step - accuracy: 0.8315 - loss: 0.3780 - val_accuracy: 0.7164 - val_loss: 0.5596
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.42715
# 352/352 - 16s - 45ms/step - accuracy: 0.8390 - loss: 0.3632 - val_accuracy: 0.7020 - val_loss: 0.5757
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.42715 to 0.41504, saving model to best_model3.keras
# 352/352 - 16s - 44ms/step - accuracy: 0.8414 - loss: 0.3553 - val_accuracy: 0.8230 - val_loss: 0.4150
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8416 - loss: 0.3572 - val_accuracy: 0.7329 - val_loss: 0.5409
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8494 - loss: 0.3435 - val_accuracy: 0.7271 - val_loss: 0.5515
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8507 - loss: 0.3438 - val_accuracy: 0.6812 - val_loss: 0.6256
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8572 - loss: 0.3329 - val_accuracy: 0.7114 - val_loss: 0.5983
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8586 - loss: 0.3258 - val_accuracy: 0.6176 - val_loss: 0.7696
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8614 - loss: 0.3216 - val_accuracy: 0.6642 - val_loss: 0.6758
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8600 - loss: 0.3210 - val_accuracy: 0.7644 - val_loss: 0.5082
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8620 - loss: 0.3172 - val_accuracy: 0.7129 - val_loss: 0.5980
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8658 - loss: 0.3161 - val_accuracy: 0.7265 - val_loss: 0.5841
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.41504
# 352/352 - 15s - 43ms/step - accuracy: 0.8689 - loss: 0.3104 - val_accuracy: 0.7486 - val_loss: 0.5534
#
# --- Evaluating Model 3 ---
#  Model 3 Test Accuracy: 0.8250

# %% [markdown]
# ## Model 4 - 1 CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 4 Parameters ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

# --- Build Model 4 
model_4 = Sequential([
    Conv1D(64, 11, activation='relu', padding='same', input_shape=input_shape),
    Dropout(0.4),

    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Flatten(),
    Dense(1, activation='sigmoid')
])

# --- Compile ---
model_4.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

# --- Callbacks ---
checkpoint = ModelCheckpoint('best_model4.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model_4.summary()

# --- Train Model 4 ---
print("\n--- Training Model 4 ---")
history_4 = model_4.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

# --- Evaluate Model 4 ---
print("\n--- Evaluating Model 4 ---")
test_loss_4, test_acc_4 = model_4.evaluate(X_test, y_test, verbose=0)
print(f"Model 4 Test Accuracy: {test_acc_4:.4f}")
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_22 (Conv1D)              │ (None, 1000, 64)       │         2,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_42 (Dropout)            │ (None, 1000, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_19 (MaxPooling1D) │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_43 (Dropout)            │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_11 (Flatten)            │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 1)              │        32,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,881 (136.25 KB)
#  Trainable params: 34,881 (136.25 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 4 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.99358, saving model to best_model4.keras
# 352/352 - 7s - 20ms/step - accuracy: 0.6194 - loss: 0.6598 - val_accuracy: 0.0012 - val_loss: 0.9936
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.99358 to 0.72015, saving model to best_model4.keras
# 352/352 - 7s - 19ms/step - accuracy: 0.6568 - loss: 0.6167 - val_accuracy: 0.5002 - val_loss: 0.7202
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.7135 - loss: 0.5605 - val_accuracy: 0.4080 - val_loss: 0.8158
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.7454 - loss: 0.5148 - val_accuracy: 0.3074 - val_loss: 0.9907
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.7679 - loss: 0.4811 - val_accuracy: 0.3442 - val_loss: 1.0047
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.7869 - loss: 0.4520 - val_accuracy: 0.4792 - val_loss: 0.8612
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.7986 - loss: 0.4342 - val_accuracy: 0.4986 - val_loss: 0.8556
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.8045 - loss: 0.4253 - val_accuracy: 0.5364 - val_loss: 0.8230
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.8119 - loss: 0.4095 - val_accuracy: 0.4577 - val_loss: 0.9546
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.8173 - loss: 0.3980 - val_accuracy: 0.6011 - val_loss: 0.7248
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.72015
# 352/352 - 7s - 19ms/step - accuracy: 0.8205 - loss: 0.3907 - val_accuracy: 0.5160 - val_loss: 0.8740
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.72015
# 352/352 - 7s - 20ms/step - accuracy: 0.8246 - loss: 0.3855 - val_accuracy: 0.5398 - val_loss: 0.8421
#
# --- Evaluating Model 4 ---
# Model 4 Test Accuracy: 0.6690

# %% [markdown]
# ## Model 5 - 2 CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 5 Parameters ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

# --- Build Model 5 
model_5 = Sequential([
    Conv1D(64, 11, activation='relu', padding='same', input_shape=input_shape),
    Dropout(0.3),

    Conv1D(32, 7, activation='relu', padding='same'),
    Dropout(0.3),

    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Flatten(),
    Dense(1, activation='sigmoid')
])

# --- Compile ---
model_5.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

# --- Callbacks ---
checkpoint = ModelCheckpoint('best_model5.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model_5.summary()

# --- Train Model 5 ---
print("\n--- Training Model 5 ---")
history_5 = model_5.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

# --- Evaluate Model 5 ---
print("\n--- Evaluating Model 5 ---")
test_loss_5, test_acc_5 = model_5.evaluate(X_test, y_test, verbose=0)
print(f" Model 5 Test Accuracy: {test_acc_5:.4f}")
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_23 (Conv1D)              │ (None, 1000, 64)       │         2,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 1000, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_24 (Conv1D)              │ (None, 1000, 32)       │        14,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 1000, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_20 (MaxPooling1D) │ (None, 500, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 500, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_12 (Flatten)            │ (None, 16000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │        16,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,249 (129.88 KB)
#  Trainable params: 33,249 (129.88 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 5 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.81259, saving model to best_model5.keras
# 352/352 - 18s - 52ms/step - accuracy: 0.6236 - loss: 0.6610 - val_accuracy: 0.0046 - val_loss: 0.8126
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 0.81259
# 352/352 - 18s - 50ms/step - accuracy: 0.6242 - loss: 0.6472 - val_accuracy: 0.0021 - val_loss: 0.9487
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.81259 to 0.76536, saving model to best_model5.keras
# 352/352 - 18s - 51ms/step - accuracy: 0.6498 - loss: 0.6246 - val_accuracy: 0.4359 - val_loss: 0.7654
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.76536
# 352/352 - 18s - 50ms/step - accuracy: 0.6869 - loss: 0.5864 - val_accuracy: 0.3390 - val_loss: 0.8641
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.76536
# 352/352 - 18s - 50ms/step - accuracy: 0.7142 - loss: 0.5588 - val_accuracy: 0.2521 - val_loss: 1.0023
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.76536
# 352/352 - 18s - 50ms/step - accuracy: 0.7354 - loss: 0.5303 - val_accuracy: 0.2800 - val_loss: 1.0825
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.76536 to 0.73711, saving model to best_model5.keras
# 352/352 - 18s - 51ms/step - accuracy: 0.7467 - loss: 0.5162 - val_accuracy: 0.5286 - val_loss: 0.7371
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.73711 to 0.65552, saving model to best_model5.keras
# 352/352 - 18s - 51ms/step - accuracy: 0.7567 - loss: 0.5000 - val_accuracy: 0.6265 - val_loss: 0.6555
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.65552
# 352/352 - 18s - 50ms/step - accuracy: 0.7660 - loss: 0.4843 - val_accuracy: 0.4332 - val_loss: 0.9032
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.65552
# 352/352 - 18s - 51ms/step - accuracy: 0.7757 - loss: 0.4704 - val_accuracy: 0.5633 - val_loss: 0.7471
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.65552 to 0.65327, saving model to best_model5.keras
# 352/352 - 18s - 50ms/step - accuracy: 0.7849 - loss: 0.4569 - val_accuracy: 0.6340 - val_loss: 0.6533
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.65327
# 352/352 - 18s - 50ms/step - accuracy: 0.7910 - loss: 0.4459 - val_accuracy: 0.5142 - val_loss: 0.8131
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.65327
# 352/352 - 18s - 51ms/step - accuracy: 0.7967 - loss: 0.4369 - val_accuracy: 0.4499 - val_loss: 0.9241
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.65327
# 352/352 - 18s - 51ms/step - accuracy: 0.8016 - loss: 0.4281 - val_accuracy: 0.4771 - val_loss: 0.8956
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.65327
# 352/352 - 18s - 51ms/step - accuracy: 0.8054 - loss: 0.4230 - val_accuracy: 0.5147 - val_loss: 0.8282
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.65327
# 352/352 - 18s - 51ms/step - accuracy: 0.8110 - loss: 0.4110 - val_accuracy: 0.5339 - val_loss: 0.8256
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.65327
# 352/352 - 18s - 51ms/step - accuracy: 0.8124 - loss: 0.4049 - val_accuracy: 0.5364 - val_loss: 0.8135
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.65327
# 352/352 - 18s - 52ms/step - accuracy: 0.8165 - loss: 0.4049 - val_accuracy: 0.5172 - val_loss: 0.8407
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.65327
# 352/352 - 18s - 52ms/step - accuracy: 0.8209 - loss: 0.3938 - val_accuracy: 0.6173 - val_loss: 0.6893
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.65327
# 352/352 - 18s - 52ms/step - accuracy: 0.8248 - loss: 0.3858 - val_accuracy: 0.6450 - val_loss: 0.6638
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.65327
# 352/352 - 18s - 52ms/step - accuracy: 0.8265 - loss: 0.3857 - val_accuracy: 0.5697 - val_loss: 0.7717
#
# --- Evaluating Model 5 ---
#  Model 5 Test Accuracy: 0.7310

# %% [markdown]
# ## Model 6 - 3 CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 6 Parameters ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

# --- Build Model 6 
model_6 = Sequential([
    Conv1D(32, 11, activation='relu', input_shape=input_shape),  
    Dropout(0.3),

    Conv1D(64, 7, activation='relu'),  
    Dropout(0.3),

    Conv1D(32, 5, activation='relu'),  
    Dropout(0.3),

    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Flatten(),
    Dense(1, activation='sigmoid')
])

# --- Compile ---
model_6.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

# --- Callbacks ---
checkpoint = ModelCheckpoint('best_model6.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model_6.summary()
# --- Train Model 6 ---
print("\n--- Training Model 6 ---")
history_6 = model_6.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

# --- Evaluate Model 6 ---
print("\n--- Evaluating Model 6 ---")
test_loss_6, test_acc_6 = model_6.evaluate(X_test, y_test, verbose=0)
print(f"Model 6 Test Accuracy: {test_acc_6:.4f}")
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_25 (Conv1D)              │ (None, 990, 32)        │         1,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 990, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_26 (Conv1D)              │ (None, 984, 64)        │        14,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 984, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_27 (Conv1D)              │ (None, 980, 32)        │        10,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 980, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_21 (MaxPooling1D) │ (None, 490, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 490, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_13 (Flatten)            │ (None, 15680)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 1)              │        15,681 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,793 (163.25 KB)
#  Trainable params: 41,793 (163.25 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 6 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.78335, saving model to best_model6.keras
# 352/352 - 26s - 73ms/step - accuracy: 0.6236 - loss: 0.6617 - val_accuracy: 5.3305e-04 - val_loss: 0.7833
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 0
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.29383
# 352/352 - 24s - 67ms/step - accuracy: 0.8300 - loss: 0.3700 - val_accuracy: 0.8532 - val_loss: 0.3499
#
# --- Evaluating Model 6 ---
# Model 6 Test Accuracy: 0.7595

# %% [markdown]
# ## MOdel 7 - 1 CNN LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Bidirectional, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Model 7 (Fast) ---
input_shape = (1000, 4)
learning_rate = 0.001
loss_fn = 'binary_crossentropy'
metrics = ['accuracy']

model_7 = Sequential([
    Conv1D(32, 7, activation='relu', input_shape=input_shape),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Bidirectional(LSTM(16, return_sequences=False)),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])

model_7.compile(
    optimizer=Adam(learning_rate),
    loss=loss_fn,
    metrics=metrics
)

checkpoint = ModelCheckpoint('best_model7.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
model_7.summary()
print("\n--- Training Model 7 ---")
history_7 = model_7.fit(
    X_train, y_train,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop],
    verbose=2
)

print("\n--- Evaluating Model 7 ---")
test_loss_7, test_acc_7 = model_7.evaluate(X_test, y_test, verbose=0)
print(f"Model 7 Test Accuracy : {test_acc_7:.4f}")
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_28 (Conv1D)              │ (None, 994, 32)        │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_22 (MaxPooling1D) │ (None, 497, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 497, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 32)             │         6,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,233 (28.25 KB)
#  Trainable params: 7,233 (28.25 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Training Model 7 ---
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.97886, saving model to best_model7.keras
# 352/352 - 32s - 90ms/step - accuracy: 0.6233 - loss: 0.6638 - val_accuracy: 0.0000e+00 - val_loss: 0.9789
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.97886 to 0.97770, saving model to best_model7.keras
# 352/352 - 34s - 96ms/step - accuracy: 0.6251 - loss: 0.6611 - val_accuracy: 0.0000e+00 - val_loss: 0.9777
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.97770 to 0.95118, saving model to best_model7.keras
# 352/352 - 33s - 94ms/step - accuracy: 0.6249 - loss: 0.6600 - val_accuracy: 0.0000e+00 - val_loss: 0.9512
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.95118 to 0.93085, saving model to best_model7.keras
# 352/352 - 33s - 93ms/step - accuracy: 0.6254 - loss: 0.6583 - val_accuracy: 0.0073 - val_loss: 0.9309
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.93085
# 352/352 - 33s - 93ms/step - accuracy: 0.6284 - loss: 0.6540 - val_accuracy: 0.0000e+00 - val_loss: 1.0363
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.93085
# 352/352 - 33s - 92ms/step - accuracy: 0.6240 - loss: 0.6563 - val_accuracy: 0.0041 - val_loss: 0.9902
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.93085 to 0.89267, saving model to best_model7.keras
# 352/352 - 32s - 92ms/step - accuracy: 0.6224 - loss: 0.6580 - val_accuracy: 0.0011 - val_loss: 0.8927
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6232 - loss: 0.6570 - val_accuracy: 0.0000e+00 - val_loss: 0.9787
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6256 - loss: 0.6556 - val_accuracy: 0.0039 - val_loss: 0.9673
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6319 - loss: 0.6479 - val_accuracy: 0.0041 - val_loss: 0.9386
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.89267
# 352/352 - 33s - 92ms/step - accuracy: 0.6253 - loss: 0.6571 - val_accuracy: 0.0439 - val_loss: 0.9403
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6267 - loss: 0.6540 - val_accuracy: 0.0000e+00 - val_loss: 1.0428
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6286 - loss: 0.6509 - val_accuracy: 0.0000e+00 - val_loss: 0.9581
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6257 - loss: 0.6538 - val_accuracy: 0.0034 - val_loss: 1.0967
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.89267
# 352/352 - 32s - 92ms/step - accuracy: 0.6237 - loss: 0.6521 - val_accuracy: 0.0028 - val_loss: 0.9346
#
# --- Evaluating Model 7 ---
# Model 7 Test Accuracy : 0.5000
